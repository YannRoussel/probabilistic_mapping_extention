# %%
import pandas as pd
import numpy as np

# %%
extended_p_me_t = pd.read_csv("../probabilistic_mapping_extention/extended_p_me_t.csv", index_col=0)

np.sum(extended_p_me_t, axis=1)
# Out:
# 0008_IT_EP-CLA_Glut_1    0.0
# 0020_IT_EP-CLA_Glut_3    0.0
# 0042_L6_IT_CTX_Glut_2    1.0
# 0049_L6_IT_CTX_Glut_4    1.0
# 0054_L6_IT_CTX_Glut_5    0.0
#                         ...
# 5318_DC_NN_1             3.0
# 5319_B_cells_NN_1        3.0
# 5320_ILC_NN_2            3.0
# 5321_NK_cells_NN_3       3.0
# 5322_T_cells_NN_4        3.0
# Length: 5322, dtype: float64

# %%
common_t_types = extended_p_me_t.index
msk_t_types = np.asarray([("IMN" not in x) & ("NN" not in x) for x in common_t_types])
common_t_types = common_t_types[msk_t_types]

extended_p_me_t = extended_p_me_t.reindex(common_t_types, axis=0)

np.unique(np.asarray([x.split("_")[-2] for x in common_t_types]))
# Out:
# array(['Chol', 'Dopa', 'Dopa-Gaba', 'Gaba', 'Gaba-Chol', 'Gaba-Glut',
#        'Glut', 'Glut-Chol', 'Glut-Sero', 'Gly-Gaba', 'Glyc-Gaba',
#        'Hist-Gaba'], dtype='<U9')

# %%
np.sum(extended_p_me_t, axis=1)
# Out:
# 0008_IT_EP-CLA_Glut_1     0.000000
# 0020_IT_EP-CLA_Glut_3     0.000000
# 0042_L6_IT_CTX_Glut_2     1.000000
# 0049_L6_IT_CTX_Glut_4     1.000000
# 0054_L6_IT_CTX_Glut_5     0.000000
#                             ...
# 5201_CB_Granule_Glut_2    2.333333
# 5202_DCO_UBC_Glut_1       2.583333
# 5203_DCO_UBC_Glut_1       3.888095
# 5204_DCO_UBC_Glut_1       3.047619
# 5205_DCO_UBC_Glut_1       2.000000
# Length: 5168, dtype: float64

# %%
extended_p_me_t = extended_p_me_t.div(np.sum(extended_p_me_t, axis=1), axis=0)
np.sum(extended_p_me_t, axis=1)
# Out:
# 0008_IT_EP-CLA_Glut_1     0.0
# 0020_IT_EP-CLA_Glut_3     0.0
# 0042_L6_IT_CTX_Glut_2     1.0
# 0049_L6_IT_CTX_Glut_4     1.0
# 0054_L6_IT_CTX_Glut_5     0.0
#                          ...
# 5201_CB_Granule_Glut_2    1.0
# 5202_DCO_UBC_Glut_1       1.0
# 5203_DCO_UBC_Glut_1       1.0
# 5204_DCO_UBC_Glut_1       1.0
# 5205_DCO_UBC_Glut_1       1.0
# Length: 5168, dtype: float64

# %%
extended_p_me_t
# Out:
#                         IN_dend_0_ax_0|bAC  IN_dend_0_ax_2|bAC  \
# 0008_IT_EP-CLA_Glut_1                  NaN                 NaN
# 0020_IT_EP-CLA_Glut_3                  NaN                 NaN
# 0042_L6_IT_CTX_Glut_2                  NaN                 NaN
# 0049_L6_IT_CTX_Glut_4                  NaN                 NaN
# 0054_L6_IT_CTX_Glut_5                  NaN                 NaN
# ...                                    ...                 ...
# 5201_CB_Granule_Glut_2                 0.0                 0.0
# 5202_DCO_UBC_Glut_1                    0.0                 0.0
# 5203_DCO_UBC_Glut_1                    0.0                 0.0
# 5204_DCO_UBC_Glut_1                    0.0                 0.0
# 5205_DCO_UBC_Glut_1                    0.0                 0.0
#
#                         IN_dend_0_ax_3|bAC  IN_dend_0_ax_4|bAC  \
# 0008_IT_EP-CLA_Glut_1                  NaN                 NaN
# 0020_IT_EP-CLA_Glut_3                  NaN                 NaN
# 0042_L6_IT_CTX_Glut_2                  NaN                 NaN
# 0049_L6_IT_CTX_Glut_4                  NaN                 NaN
# 0054_L6_IT_CTX_Glut_5                  NaN                 NaN
# ...                                    ...                 ...
# 5201_CB_Granule_Glut_2            0.000000            0.000000
# 5202_DCO_UBC_Glut_1               0.024226            0.000000
# 5203_DCO_UBC_Glut_1               0.000000            0.049096
# 5204_DCO_UBC_Glut_1               0.020535            0.000000
# 5205_DCO_UBC_Glut_1               0.046388            0.000000
#
#                         IN_dend_0_ax_5|bAC  IN_dend_0_ax_6|bAC  \
# 0008_IT_EP-CLA_Glut_1                  NaN                 NaN
# 0020_IT_EP-CLA_Glut_3                  NaN                 NaN
# 0042_L6_IT_CTX_Glut_2                  NaN                 NaN
# 0049_L6_IT_CTX_Glut_4                  NaN                 NaN
# 0054_L6_IT_CTX_Glut_5                  NaN                 NaN
# ...                                    ...                 ...
# 5201_CB_Granule_Glut_2                 0.0                 0.0
# 5202_DCO_UBC_Glut_1                    0.0                 0.0
# 5203_DCO_UBC_Glut_1                    0.0                 0.0
# 5204_DCO_UBC_Glut_1                    0.0                 0.0
# 5205_DCO_UBC_Glut_1                    0.0                 0.0
#
#                         IN_dend_0_ax_8|bAC  IN_dend_0_ax_9|bAC  \
# 0008_IT_EP-CLA_Glut_1                  NaN                 NaN
# 0020_IT_EP-CLA_Glut_3                  NaN                 NaN
# 0042_L6_IT_CTX_Glut_2                  NaN                 NaN
# 0049_L6_IT_CTX_Glut_4                  NaN                 NaN
# 0054_L6_IT_CTX_Glut_5                  NaN                 NaN
# ...                                    ...                 ...
# 5201_CB_Granule_Glut_2            0.000000                 0.0
# 5202_DCO_UBC_Glut_1               0.000000                 0.0
# 5203_DCO_UBC_Glut_1               0.023741                 0.0
# 5204_DCO_UBC_Glut_1               0.000000                 0.0
# 5205_DCO_UBC_Glut_1               0.000000                 0.0
#
#                         IN_dend_1_ax_0|bAC  IN_dend_1_ax_1|bAC  ...  \
# 0008_IT_EP-CLA_Glut_1                  NaN                 NaN  ...
# 0020_IT_EP-CLA_Glut_3                  NaN                 NaN  ...
# 0042_L6_IT_CTX_Glut_2                  NaN                 NaN  ...
# 0049_L6_IT_CTX_Glut_4                  NaN                 NaN  ...
# 0054_L6_IT_CTX_Glut_5                  NaN                 NaN  ...
# ...                                    ...                 ...  ...
# 5201_CB_Granule_Glut_2            0.000000                 0.0  ...
# 5202_DCO_UBC_Glut_1               0.016008                 0.0  ...
# 5203_DCO_UBC_Glut_1               0.010636                 0.0  ...
# 5204_DCO_UBC_Glut_1               0.013569                 0.0  ...
# 5205_DCO_UBC_Glut_1               0.000000                 0.0  ...
#
#                         PC_dend_2_ax_7|dSTUT  PC_dend_2_ax_8|dSTUT  \
# 0008_IT_EP-CLA_Glut_1                    NaN                   NaN
# 0020_IT_EP-CLA_Glut_3                    NaN                   NaN
# 0042_L6_IT_CTX_Glut_2                    NaN                   NaN
# 0049_L6_IT_CTX_Glut_4                    NaN                   NaN
# 0054_L6_IT_CTX_Glut_5                    NaN                   NaN
# ...                                      ...                   ...
# 5201_CB_Granule_Glut_2                   0.0                   0.0
# 5202_DCO_UBC_Glut_1                      0.0                   0.0
# 5203_DCO_UBC_Glut_1                      0.0                   0.0
# 5204_DCO_UBC_Glut_1                      0.0                   0.0
# 5205_DCO_UBC_Glut_1                      0.0                   0.0
#
#                         PC_dend_3_ax_0|dSTUT  PC_dend_3_ax_4|dSTUT  \
# 0008_IT_EP-CLA_Glut_1                    NaN                   NaN
# 0020_IT_EP-CLA_Glut_3                    NaN                   NaN
# 0042_L6_IT_CTX_Glut_2                    NaN                   NaN
# 0049_L6_IT_CTX_Glut_4                    NaN                   NaN
# 0054_L6_IT_CTX_Glut_5                    NaN                   NaN
# ...                                      ...                   ...
# 5201_CB_Granule_Glut_2                   0.0                   0.0
# 5202_DCO_UBC_Glut_1                      0.0                   0.0
# 5203_DCO_UBC_Glut_1                      0.0                   0.0
# 5204_DCO_UBC_Glut_1                      0.0                   0.0
# 5205_DCO_UBC_Glut_1                      0.0                   0.0
#
#                         PC_dend_3_ax_6|dSTUT  PC_dend_3_ax_7|dSTUT  \
# 0008_IT_EP-CLA_Glut_1                    NaN                   NaN
# 0020_IT_EP-CLA_Glut_3                    NaN                   NaN
# 0042_L6_IT_CTX_Glut_2                    NaN                   NaN
# 0049_L6_IT_CTX_Glut_4                    NaN                   NaN
# 0054_L6_IT_CTX_Glut_5                    NaN                   NaN
# ...                                      ...                   ...
# 5201_CB_Granule_Glut_2                   0.0                   0.0
# 5202_DCO_UBC_Glut_1                      0.0                   0.0
# 5203_DCO_UBC_Glut_1                      0.0                   0.0
# 5204_DCO_UBC_Glut_1                      0.0                   0.0
# 5205_DCO_UBC_Glut_1                      0.0                   0.0
#
#                         PC_dend_3_ax_8|dSTUT  PC_dend_8_ax_4|dSTUT  \
# 0008_IT_EP-CLA_Glut_1                    NaN                   NaN
# 0020_IT_EP-CLA_Glut_3                    NaN                   NaN
# 0042_L6_IT_CTX_Glut_2                    NaN                   NaN
# 0049_L6_IT_CTX_Glut_4                    NaN                   NaN
# 0054_L6_IT_CTX_Glut_5                    NaN                   NaN
# ...                                      ...                   ...
# 5201_CB_Granule_Glut_2                   0.0                   0.0
# 5202_DCO_UBC_Glut_1                      0.0                   0.0
# 5203_DCO_UBC_Glut_1                      0.0                   0.0
# 5204_DCO_UBC_Glut_1                      0.0                   0.0
# 5205_DCO_UBC_Glut_1                      0.0                   0.0
#
#                         PC_dend_8_ax_7|dSTUT  PC_dend_8_ax_8|dSTUT
# 0008_IT_EP-CLA_Glut_1                    NaN                   NaN
# 0020_IT_EP-CLA_Glut_3                    NaN                   NaN
# 0042_L6_IT_CTX_Glut_2                    NaN                   NaN
# 0049_L6_IT_CTX_Glut_4                    NaN                   0.0
# 0054_L6_IT_CTX_Glut_5                    NaN                   NaN
# ...                                      ...                   ...
# 5201_CB_Granule_Glut_2                   0.0                   0.0
# 5202_DCO_UBC_Glut_1                      0.0                   0.0
# 5203_DCO_UBC_Glut_1                      0.0                   0.0
# 5204_DCO_UBC_Glut_1                      0.0                   0.0
# 5205_DCO_UBC_Glut_1                      0.0                   0.0
#
# [5168 rows x 924 columns]

# %%
np.multiply(np.shape(extended_p_me_t)[0], np.shape(extended_p_me_t)[1])
# Out:
# 4775232

# %%
df_col = []
for t in extended_p_me_t.index:
    df_ = extended_p_me_t.T[t].T
    df_ = df_.rename({x : "|".join([x, t]) for x in extended_p_me_t.columns}, axis=0)
    df_col.append(df_)

# p_met_t = pd.concat(df_col, axis=1)

# %%
pd.concat(df_col, axis=0)
# Out:
# IN_dend_0_ax_0|bAC|0008_IT_EP-CLA_Glut_1    NaN
# IN_dend_0_ax_2|bAC|0008_IT_EP-CLA_Glut_1    NaN
# IN_dend_0_ax_3|bAC|0008_IT_EP-CLA_Glut_1    NaN
# IN_dend_0_ax_4|bAC|0008_IT_EP-CLA_Glut_1    NaN
# IN_dend_0_ax_5|bAC|0008_IT_EP-CLA_Glut_1    NaN
#                                            ...
# PC_dend_3_ax_7|dSTUT|5205_DCO_UBC_Glut_1    0.0
# PC_dend_3_ax_8|dSTUT|5205_DCO_UBC_Glut_1    0.0
# PC_dend_8_ax_4|dSTUT|5205_DCO_UBC_Glut_1    0.0
# PC_dend_8_ax_7|dSTUT|5205_DCO_UBC_Glut_1    0.0
# PC_dend_8_ax_8|dSTUT|5205_DCO_UBC_Glut_1    0.0
# Length: 4775232, dtype: float64
